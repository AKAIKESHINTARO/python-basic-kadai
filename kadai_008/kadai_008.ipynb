# %%
num1=5
num2="5"
if num1==int(num2):
  print("num1とnum2は等しいです。")
# Out:
# num1とnum2は等しいです。

# %%
num = random.randint(0, 4)
print(num)
if num == 4:
  print("大当たりです")
# Out:
# 0

# %%
num = random.randint(0, 4)
print(num)
if num == 4:
  print("大当たりです")
else :
  print("はずれです")
# Out:
# 4
# 大当たりです

# %%
num = random.randint(0,4)
print(num)
if num == 4:
  print("大当たりです")
elif num == 3:
  print("当たりです")
else :
  print("はずれです")
# Out:
# 3
# 当たりです

# %%
num = random.randint(0,4)
print(num)
if 1 < num and num < 3:
  print("変数numは1よりお大きく、3より小さいです")
else :
  print("and条件が成り立ちませんでした")

if num == 1 or num ==3:
  print("変数numは１または３です")
else :
  print("or条件が成立ちませんでした")
# Out:
# 4
# and条件が成り立ちませんでした
# or条件が成立ちませんでした

# %%
var = random.randint(0,100)
print(var)
if var % 3 == 0:
  print("Fizz")
elif var % 5 == 0 :
  print("Buzz")
if var % 3 == 0 and var % 5 == 0:
  print("FizzBuzz")
else :
  print(var)
# Out:
# 7
# 7
